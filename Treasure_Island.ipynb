# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...

# %%
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.")

junction1 = input("You are now on your way to find your treasure and reach the first junction on the map. Which direction to take type R for right and L for left: ").upper()
if junction1 == "L":
    print("You are on the right track.")
else:
    print("Game Over - You have fallen into a hole and cannot get out.")
    exit()

junction2 = input("You have reached a river that is about 200 ft in width and you are a good swimmer.  Type 'W' for wait or 'S' to swim: ").upper()
if junction2 == "W":
    print(" You have made it across safely. Keep going you are getting closer")
else:
    print("Attacked by Trouts - Game Over")
    exit()

building = input("You have reached the building on the map that has the treasure. There are 3 doors each with different colours. Type 'R' to choose the red door, or type 'B' to choose the blue door, or 'Y' to choose the yellow door: ").upper()
if building == "R":
    print("Burned by fire - Game Over")
elif building == "B":
    print("Eaten by beast - Game over")
elif building == "Y":
    print("You win - The treasure is yours")
else:
    print("Game over")
# Out:
# Welcome to Treasure Island.
# Your mission is to find the treasure.
# You are now on your way to find your treasure and reach the first junction on the map. Which direction to take type R for right and L for left: l
# You are on the right track.
# You have reached a river that is about 200 ft in width and you are a good swimmer.  Type 'W' for wait or 'S' to swim: w
#  You have made it across safely. Keep going you are getting closer
# You have reached the building on the map that has the treasure. There are 3 doors each with different colours. Type 'R' to choose the red door, or type 'B' to choose the blue door, or 'Y' to choose the yellow door: y
# You win - The treasure is yours

# %% [markdown]
# So, the tech stack for this game is quite simple - it’s just Python! No additional libraries or frameworks were used in this particular code snippet. However, if you wanted to expand this game, you might consider using a library like curses for more advanced console output, or even porting your game to a graphical framework like pygame. But for a simple text-based game like this, plain Python is all you need.
